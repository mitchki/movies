# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.feature_extraction.text import CountVectorizer

# %matplotlib inline

# %%
movies = pd.read_pickle('movies_all.pkl')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4538 entries, 0 to 4537
# Data columns (total 34 columns):
# color                        4522 non-null object
# director_name                4468 non-null object
# num_critic_for_reviews       4498 non-null float64
# duration                     4527 non-null float64
# director_facebook_likes      4468 non-null float64
# actor_3_facebook_likes       4522 non-null float64
# actor_2_name                 4529 non-null object
# actor_1_facebook_likes       4532 non-null float64
# gross                        3810 non-null float64
# genres                       4538 non-null object
# actor_1_name                 4532 non-null object
# movie_title                  4538 non-null object
# num_voted_users              4538 non-null int64
# cast_total_facebook_likes    4538 non-null int64
# actor_3_name                 4522 non-null object
# facenumber_in_poster         4529 non-null float64
# ...

# %%
plt.scatter(movies['gross'],movies['DomesticGross'])
plt.scatter(movies['gross'],movies['WorldwideGross'])

# %%
movies['title_year'].value_counts().sort
# Out:
# <bound method Series.sort of 2014.0    244
# 2009.0    219
# 2013.0    216
# 2006.0    212
# 2015.0    208
# 2008.0    204
# 2010.0    202
# 2011.0    201
# 2012.0    198
# 2004.0    195
# 2005.0    191
# 2002.0    187
# 2007.0    184
# 2001.0    167
# 2003.0    155
# 2000.0    153
# 1999.0    149
# 1998.0    123
# 1997.0    101
# 2016.0     99
# 1996.0     95
# 1995.0     63
# 1994.0     51
# 1993.0     43
# 1984.0     34
# 1992.0     34
# 1982.0     32
# 1988.0     31
# 1981.0     31
# 1990.0     30
#          ...
# 1953.0      4
# 1967.0      3
# 1952.0      3
# 1946.0      3
# 1948.0      3
# 1947.0      3
# 1956.0      3
# 1960.0      3
# 1951.0      2
# 1942.0      2
# 1929.0      2
# 1933.0      2
# 1937.0      2
# 1939.0      2
# 1959.0      2
# 1957.0      2
# 1949.0      2
# 1943.0      1
# 1944.0      1
# 1941.0      1
# 1950.0      1
# 1938.0      1
# 1958.0      1
# 1936.0      1
# 1935.0      1
# 1934.0      1
# 1930.0      1
# 1927.0      1
# 1925.0      1
# ...

# %%
hist.movies['']

# %%
movies['color'].value_counts()
# Out:
# Color               4341
#  Black and White     181
# Name: color, dtype: int64

# %%
movies['content_rating'].value_counts()
# Out:
# R            1933
# PG-13        1368
# PG            641
# Not Rated      94
# G              93
# Unrated        57
# Approved       50
# TV-14          20
# TV-MA          11
# X              11
# TV-PG          10
# Passed          8
# NC-17           7
# TV-G            7
# GP              5
# M               3
# TV-Y            1
# TV-Y7           1
# Name: content_rating, dtype: int64

# %%
by_rating = sns.stripplot(x="content_rating", y="DomesticGross", data=movies, jitter=True, alpha=0.5);

plt.setp(by_rating.get_xticklabels(), rotation=45);

# %%
sns.pairplot(movies, hue="content_rating")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-0261a56ad182> in <module>()
# ----> 1 sns.pairplot(movies, hue="content_rating")
#
# /home/kmitchell/anaconda2/envs/py35/lib/python3.5/site-packages/seaborn/linearmodels.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, size, aspect, dropna, plot_kws, diag_kws, grid_kws)
#    1607     if grid.square_grid:
#    1608         if diag_kind == "hist":
# -> 1609             grid.map_diag(plt.hist, **diag_kws)
#    1610         elif diag_kind == "kde":
#    1611             diag_kws["legend"] = False
#
# /home/kmitchell/anaconda2/envs/py35/lib/python3.5/site-packages/seaborn/axisgrid.py in map_diag(self, func, **kwargs)
#    1346                 else:
#    1347                     func(vals, color=self.palette, histtype="barstacked",
# ...
