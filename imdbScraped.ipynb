# %% [markdown]
# Import kaggle imbd file
#
# https://www.kaggle.com/forums/f/1471/imdb-5000-movie-dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.feature_extraction.text import CountVectorizer

# %matplotlib inline

# %%
df = pd.read_pickle("movies_stars.pkl")
#df = pd.read_csv('movie_metadata.csv')
df.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4  Color     Andrew Stanton                   462.0     132.0
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    475.0                   530.0   Samantha Morton
#
#    actor_1_facebook_likes        gross                           genres  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4538 entries, 0 to 4537
# Data columns (total 35 columns):
# color                        4522 non-null object
# director_name                4468 non-null object
# num_critic_for_reviews       4498 non-null float64
# duration                     4527 non-null float64
# director_facebook_likes      4468 non-null float64
# actor_3_facebook_likes       4522 non-null float64
# actor_2_name                 4538 non-null object
# actor_1_facebook_likes       4532 non-null float64
# gross                        3810 non-null float64
# genres                       4538 non-null object
# actor_1_name                 4538 non-null object
# movie_title                  4538 non-null object
# num_voted_users              4538 non-null int64
# cast_total_facebook_likes    4538 non-null int64
# actor_3_name                 4538 non-null object
# facenumber_in_poster         4529 non-null float64
# ...

# %%
df.to_pickle('movie_metadata_stars.pkl')

# %%
df2 = pd.read_pickle("MovieFinance.pkl")
#

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5229 entries, 0 to 5228
# Data columns (total 6 columns):
# DomesticGross       5229 non-null int64
# Movie               5229 non-null object
# ProductionBudget    5229 non-null int64
# ReleaseDate         5229 non-null datetime64[ns]
# WorldwideGross      5229 non-null int64
# ix                  5229 non-null object
# dtypes: datetime64[ns](1), int64(3), object(2)
# memory usage: 245.2+ KB

# %%
df2['movie_title'] = df2['Movie']

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5229 entries, 0 to 5228
# Data columns (total 7 columns):
# DomesticGross       5229 non-null int64
# Movie               5229 non-null object
# ProductionBudget    5229 non-null int64
# ReleaseDate         5229 non-null datetime64[ns]
# WorldwideGross      5229 non-null int64
# ix                  5229 non-null object
# movie_title         5229 non-null object
# dtypes: datetime64[ns](1), int64(3), object(3)
# memory usage: 286.0+ KB

# %%
## list comprehension [x**2 for x in range(10)]
df['movie_title'] = [title.strip() for title in df['movie_title']]

# %%
df3 = pd.merge(df, df2, how='inner', on='movie_title')

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4810 entries, 0 to 4809
# Data columns (total 41 columns):
# color                        4794 non-null object
# director_name                4740 non-null object
# num_critic_for_reviews       4766 non-null float64
# duration                     4799 non-null float64
# director_facebook_likes      4740 non-null float64
# actor_3_facebook_likes       4794 non-null float64
# actor_2_name                 4810 non-null object
# actor_1_facebook_likes       4804 non-null float64
# gross                        4022 non-null float64
# genres                       4810 non-null object
# actor_1_name                 4810 non-null object
# movie_title                  4810 non-null object
# num_voted_users              4810 non-null int64
# cast_total_facebook_likes    4810 non-null int64
# actor_3_name                 4810 non-null object
# facenumber_in_poster         4801 non-null float64
# ...

# %%
df3.head(20)
# Out:
#     color      director_name  num_critic_for_reviews  duration  \
# 0   Color      James Cameron                   723.0     178.0
# 1   Color     Gore Verbinski                   302.0     169.0
# 2   Color         Sam Mendes                   602.0     148.0
# 3   Color  Christopher Nolan                   813.0     164.0
# 4   Color     Andrew Stanton                   462.0     132.0
# 5   Color          Sam Raimi                   392.0     156.0
# 6   Color          Sam Raimi                   392.0     156.0
# 7   Color       Nathan Greno                   324.0     100.0
# 8   Color        Joss Whedon                   635.0     141.0
# 9   Color        David Yates                   375.0     153.0
# 10  Color        Zack Snyder                   673.0     183.0
# 11  Color       Bryan Singer                   434.0     169.0
# 12  Color       Marc Forster                   403.0     106.0
# 13  Color     Gore Verbinski                   313.0     151.0
# ...

# %%
df3['num_stars'].value_counts()
# Out:
# 0     3830
# 1      465
# 2      254
# 3      140
# 4       67
# 5       22
# 7       11
# 6       10
# 9        4
# 8        4
# 11       1
# 14       1
# 13       1
# Name: num_stars, dtype: int64

# %%
df3.to_pickle('movies_all_stars.pkl')
